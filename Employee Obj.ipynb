# %%
class Employee:
    pass

emp_1=Employee()
emp_2=Employee()

# %%
print(emp_1)
print(emp_2)

# %%
emp_1.first="Soumyadip"
emp_1.last="Chowdhury"
emp_1.email="soumyadip.cmp@gmail.com"
emp_1.pay=90000

# %%
print(emp_1)
print(emp_1.first)
print(emp_1.last)
print(emp_1.email)
print(emp_1.pay )
# Out:
# ...
# Soumyadip
# Chowdhury
# soumyadip.cmp@gmail.com
# 90000
